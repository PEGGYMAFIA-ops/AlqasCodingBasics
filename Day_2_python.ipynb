# %% [markdown]
# <a href="https://colab.research.google.com/github/PEGGYMAFIA-ops/AlqasCodingBasics/blob/main/Day_2_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 2: 30 days of Python
First_name = "riham"
Last_name = 'syamal'
country = 'Indonesia'
city = 'Depok'
Age = '16'
year = '2009'
is_married = 'no'
is_true = 'yes'
is_light_on = 'idk'
Favorite_Food, Favorite_Drink = 'kimchi', 'teh botol'

type(First_name)

if len(First_name) > len(Last_name):
  print("true")
else:
  print("false")

num_one = 5
num_two = 4

Results_one = num_one + num_two
Results_two = num_two - num_one
Results_three = num_one * num_two
Results_four = num_one / num_two
Results_five = num_one % num_two
Results_six = num_one ** num_two
Results_seven = num_one // num_two
print(Results_one, Results_two, Results_three, Results_four, Results_five, Results_six, Results_seven)

Circle_diameter = 30
Circum_of_circle = 30 * 3.14

def radius():
  radius = int(input("please input your radius: "))
  area = radius ** 2 * 3.14
  print(area)

radius()

print('Multiplying complex numbers: ',(1 + 1j) * (1 - 1j))a
# Out:
# false
# 9 -1 20 1.25 1 625 1
# please input your radius: 444
# 619007.04
# Multiplying complex numbers:  (2+0j)
