# %% [markdown]
# <a href="https://colab.research.google.com/github/PEGGYMAFIA-ops/AlqasCodingBasics/blob/main/Day_3_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def triangle():
  base = int(input(""))
  height = int(input(""))
  area = 0.5 * base * height
  print(area)

triangle()

sides = [int(x) for x in input("enter side lengths: ").split()]
print(sum(sides))

pi = 3.14
radian  = int(input("input ur radian"))
print(2 * pi * radian)
print(pi * radian **2)

slope1 = 1

x1, y1 = 2,2
x2, y2 = 6,10

slope2 = (y2 - y1)/(x2 - x1)
euclidian = ((y2 - y1)** 2 + (x2 - x1) ** 2) ** 0.5

print(slope2, euclidian)

if slope1 > slope2:
  print(True)
else:
  print(False)

word1, word2 = "python", "dragon"
length1, length2 = len(word1), len(word2)
if length1 == length2:
  print(f"python is '{length1}' letters long, while dragon is '{length2}' letters long")


for x in range(1, -119, -1):
    if x ** 2 + x*6 + 9 == 0:
        print(x)

print(bool('on' in 'python' and  'dragon'))
print(bool('jargon' in 'I hope this course is not full of jargon'))

float_word1 = float(length1)
string_word1 = str(length1)

print(length1, float_word1, string_word1 )

#Left off before 17
# Out:
# 2342424
# 2342
# 2742978504.0
# enter side lengths: 342
# 342
# input ur radian234
# 1469.52
# 171933.84
# 2.0 8.94427190999916
# False
# python is '6' letters long, while dragon is '6' letters long
# -3
# True
# True
# 6 6.0 6
