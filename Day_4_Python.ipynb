# %% [markdown]
# <a href="https://colab.research.google.com/github/PEGGYMAFIA-ops/AlqasCodingBasics/blob/main/Day_4_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
multiline_string = '''I am a teacher and enjoy teaching.
I didn't find anything as rewarding as empowering people.
That is why I created 30 days of python.'''
print(multiline_string)

# Another way of doing the same thing
multiline_string = """Multiline String allows you to implement line breaks and
other stuff within the string itself -- like a gdocs"""
print(multiline_string)

#\n: new line
#\t: Tab means(8 spaces)
#\\: Back slash
#\': Single quote ('
#\": Double quote (")

first_name = 'Asabeneh'
last_name = 'Yetayeh'
language = 'Python'
formated_string = 'I am %s %s. I teach %s' %(first_name, last_name, language)
print(formated_string)

language = 'Python'
first_letter = language[0]
print(first_letter) # P
second_letter = language[1]
print(second_letter) # y
last_index = len(language) - 1
last_letter = language[last_index]
print(last_letter) # n

challenge = 'thirty days of python'
# Capitalize 't' and 'y' specifically
capitalized_challenge = challenge.replace('t', 'T').replace('y', 'Y')
print(capitalized_challenge) # 'Thirty daYs of pYthon'


print('\u2603')
print(chr(65))

#First Time Using Unicode

challenge = 'thirty days of python'
print(challenge.split()) # ['thirty', 'days', 'of', 'python']
challenge = 'thirty, days, of, python'
print(challenge.split(', ')) # ['thirty', 'days', 'of', 'python']

#EXCERCISES
#1:
TDOP = ['Thirty', 'Days', 'Of', 'Python']
print('-'.join(TDOP))

CFA = ['coding', 'for', 'all']
company = ' '.join(CFA)
print(company)
print(len(company))
Empruy = (company.upper())
print(Empruy)
print(Empruy.lower())

print(company.capitalize(), company.title(), company.swapcase())
print(company[6:])


print(company.find('coding'))

PFA = company.replace('coding', 'python')
print(PFA)

print(PFA.replace('all', 'everyone'))

print(company.split( ))

CH = challenge
CO = company

COMPANIES = 'Facebook Google Microsoft Apple IBM Oracle Amazon'
print(COMPANIES.split(', '))

print(company[0])
print(company[-1])
print(company[10])

print(CO.find('c'))
print(CO.find('f'))
print(CO.rfind('l'))

BCSS = 'You cannot end a sentence with because because because is a conjunction'
print(BCSS.find('because'))

BCS = 'You cannot end a sentence with because because because is a conjunction'
substring = 'because'
print(BCS.rindex(substring))

print(BCS[31:55])
print(BCS.index(substring))

if CO.startswith('coding'):
  print(True)
else:
  False

if CO.endswith('coding'):
  print(True)
else:
  print(False)

if '30DaysOfPython'.isidentifier() == True:
  print(f'1 is {True}')
elif 'thirty_days_of_python'.isidentifier() == True:
  print(f'2 is {True}')

dAtabases = ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
print('# '.join(dAtabases))

print("I am enjoying this challenge.\nI just wonder what is next.")

radius = 10
area = 3.14 * radius ** 2
print(f"the area of a circle with radius {radius}, is {area} meters square")

lambda_operators = [
    lambda x, y: x + y, # Addition
    lambda x, y: x - y, # Subtraction
    lambda x, y: x * y, # Multiplication
    lambda x, y: x / y,  # Division
    lambda x, y: x % y,
    lambda x, y: x // y,
    lambda x, y: x**y,
]

num_a = 8
num_b = 6

print(f"Applying lambda operators to {num_a} and {num_b}:")
for op_func in lambda_operators:
    result = op_func(num_a, num_b)
    print(f"  Result: {result}")
# Out:
# I am a teacher and enjoy teaching.
# I didn't find anything as rewarding as empowering people.
# That is why I created 30 days of python.
# Multiline String allows you to implement line breaks and
# other stuff within the string itself -- like a gdocs
# I am Asabeneh Yetayeh. I teach Python
# P
# y
# n
# ThirTY daYs of pYThon
# ☃
# A
# ['thirty', 'days', 'of', 'python']
# ['thirty', 'days', 'of', 'python']
# Thirty-Days-Of-Python
# coding for all
# 14
# CODING FOR ALL
# coding for all
# Coding for all Coding For All CODING FOR ALL
#  for all
# 0
# python for all
# python for everyone
# ['coding', 'for', 'all']
# ['Facebook Google Microsoft Apple IBM Oracle Amazon']
# c
# l
#
# 0
# 7
# 13
# 31
# 47
# because because because
# 31
# True
# False
# 2 is True
# Django# Flask# Bottle# Pyramid# Falcon
# I am enjoying this challenge.
# I just wonder what is next.
# the area of a circle with radius 10, is 314.0 meters square
# Applying lambda operators to 8 and 6:
#   Result: 14
# ...
